# %% [markdown]
# # Visualize the relations between delivered energy (column name: cumEnergy_Wh) and several other key metrics

# %%
# Text wrap for nicer graph output
import textwrap
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots
# import src.viz
from src.viz import *
import sys, os
sys.path.insert(1, os.getcwd() + '\..\src')
# sys.path.insert(1, os.getcwd() + '/../src')

# %% [markdown]
# ## Energy Delivered – Choice

# %%
df1 = pd.read_csv("./data/Sessions2_20221020.csv")


# f3 = energyDelivered_DurationHrs_joint(df1)
#
# arr_Time, dept_Time = Time_processing(df1)
# f4 = energyDelivered_Arrvltime_joint(df1, arr_Time)

# %% [markdown]
# ## Energy Delivered -- Choice

# %%
energyDelivered_choice(df1)

# %%
energyDelivered_DurationHrs(df1)

# %%
energyDelivered_DurationHrs_joint(df1)

# %%
arr_Time, dept_Time = Time_processing(df1)
energyDelivered_Arrvltime_joint(df1, arr_Time)

# %%
energyDelivered_Arrvltime(df1, arr_Time)

# %%
energyDelivered_Depttime_joint(df1, dept_Time)

# %%
energyDelivered_Depttime(df1, dept_Time)
# Out:
# /home/caizhiyu/SlrpEV/pev-digital-twin/src/viz.py:143: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   f_enerDlv_dept = sns.histplot(df,

# %%
# energyDelivered_DurMaxChar(df1)

# %%
stationID_PwrDem(df1)

# %%
stationID_PwrDem_Time(df1)

# %% [markdown]
# ## This notebooks tests the plotting functions in viz.py for visualizing the historical session data

# %%
import sys, os
sys.path.insert(1, os.getcwd() + '\..\src')
sys.path.insert(1, os.getcwd() + '/../src')

# %%
from viz import * 
import pandas as pd
import matplotlib.pyplot as plt

# %%
try:
    session_data = pd.read_csv('..\data\Sessions2_20221020.csv')
except:
    session_data = pd.read_csv('../data/Sessions2_20221020.csv')

# %%
session_data.head()
# Out:
#    dcosId  userId           vehicle_model  vehicle_maxChgRate_W  siteId  \
# 0      24     605                    500e                  6600      23
# 1      26     486                 Model 3                 24000      23
# 2      30     620                    Volt                  3600      25
# 3      31     618                    Bolt                  7200      23
# 4      32     623  B-Class Electric Drive                  6000      23
#
#    stationId          connectTime      startChargeTime             Deadline  \
# 0          7  2020-11-05T10:30:16  2020-11-05T10:31:09                  NaN
# 1          3  2020-11-11T07:39:55  2020-11-11T07:39:59                  NaN
# 2         12  2020-11-13T16:19:55  2020-11-13T16:20:06  2020-11-14T04:15:00
# 3          6  2020-11-14T23:47:06  2020-11-14T23:47:16                  NaN
# 4          9  2020-11-16T11:38:44  2020-11-16T11:42:22                  NaN
#
# ...

# %%
plot_choice_per_vehicle_model(session_data)

# %%
sns.histplot(session_data, x='siteId', hue='choice', multiple='dodge')
# Out:
# <AxesSubplot: xlabel='siteId', ylabel='Count'>

# %%
sns.histplot(session_data, x='cumEnergy_Wh', hue='choice', multiple='dodge')
# Out:
# <AxesSubplot: xlabel='cumEnergy_Wh', ylabel='Count'>

# %%
plt.figure(figsize=(16, 10))
sns.heatmap(session_data.corr(), annot=True)
# Out:
# /var/folders/rn/6p4_n9750412mw__zxkgbzcm0000gn/T/ipykernel_6777/2339122495.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(session_data.corr(), annot=True)
# <AxesSubplot: >

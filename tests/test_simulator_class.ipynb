# %%
import sys, os
sys.path.insert(1, os.getcwd() + '\..\src')
sys.path.insert(1, os.getcwd() + '/../src')

# %%
from simulator import *
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# 6    10
# 7    10
# 8    10
# 9    10
# Name: arrivalDay, dtype: int64
#    arrivalDay  arrivalHour  arrivalMin  arrivalMinGlobal  durationMin  \
# 0           0         6.50         369               390          550
# 1           0         7.75         452               465          300
# 2           0         8.00         463               480          200
# 3           0         8.25         480               495          200
# 4           0         9.00         526               540          125
# 5           0        10.00         591               600          250
# 6           0        10.00         592               600          350
# 7           0        11.00         642               660          475
# 8           0        13.50         791               810          125
# 9           0        18.25        1079              1095          100
# 10          1         7.50         439              1890          125
# ...

# %% [markdown]
# # Main Simulation

# %%
sim = Simulator()

# %%
sim.run_simulation()
# Out:
# simu_run_tim 14400
# env <simpy.core.Environment object at 0x000001EFA32BF7F0>
# range(0, 14400, 15)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File C:\TeslaGit\pev-digital-twin\tests/../src\simulator.py:191, in Simulator._charger_station(self, env, input_df, run_time)
#     190 # cartype output
# --> 191 car = random.choices(models, weights=(151, 110, 86, 51, 42, 42, 28, 24, 20, 19, 15, 14))
#     192 car_type.append(car)
#
# NameError: name 'models' is not defined
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# File C:\TeslaGit\pev-digital-twin\tests/../src\simulator.py:148, in Simulator.first_process(self, env, input_df, run_length)
#     147 def first_process(self, env, input_df, run_length):
# ...

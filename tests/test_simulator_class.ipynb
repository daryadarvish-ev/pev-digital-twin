# %%
import sys, os
sys.path.insert(1, os.getcwd() + '\..\src')
sys.path.insert(1, os.getcwd() + '/../src')

# %%
from simulator import *

# %% [markdown]
# # Main Simulation

# %%
sim = Simulator()
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# 6    10
# 7    10
# 8    10
# 9    10
# Name: arrivalDay, dtype: int64
#    arrivalDay  arrivalHour  arrivalMin  arrivalMinGlobal  durationMin  \
# 0           0         6.50         369               390          550
# 1           0         6.75         388               405          575
# 2           0         7.75         452               465          300
# 3           0         8.25         480               495          200
# 4           0         9.00         526               540          125
# 5           0         9.00         530               540          500
# 6           0        10.00         592               600          350
# 7           0        11.00         642               660          475
# 8           0        13.50         791               810          125
# 9           0        18.25        1079              1095          100
# 10          1         7.50         439              1890          125
# ...

# %%
sim.run_simulation()
# Out:
# sim_run_tim 14400
# env <simpy.core.Environment object at 0x000001BB4357AA30>
# range(0, 14400, 15)
# 1
# ############################# start of iteration #############################
# curr_time =  390
# departure_time =  930
# requested_energy =  40
# Currently 1 th user is using
# After 3 iterations, we got -0.041785  improvements, and claim convergence.
# The prices for flex : 20.040444 ,  asap : 20.106171
# User's choice :  Scheduled
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File C:\TeslaGit\pev-digital-twin\tests/../src\simulator.py:272, in Simulator._charger_station(self, env, input_df, run_time)
#     271 # Daily user Flex & Scheduled List
# --> 272 self._asap_schedule_list(user, station, asap_price, flex_price)
#     273 print('the current stat of station', station)
#
# ...
